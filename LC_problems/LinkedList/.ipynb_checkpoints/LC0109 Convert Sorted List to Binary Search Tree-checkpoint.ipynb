# %% [markdown]
# 109. Convert Sorted List to Binary Search Tree
# Medium
#
# 3466
#
# 103
#
# Add to List
#
# Share
# Given the head of a singly linked list where elements are sorted in ascending order, convert it to a height balanced BST.
#
# For this problem, a height-balanced binary tree is defined as a binary tree in which the depth of the two subtrees of every node never differ by more than 1.
#
#
#
# Example 1:
#
#
# Input: head = [-10,-3,0,5,9]
# Output: [0,-3,9,-10,null,5]
# Explanation: One possible answer is [0,-3,9,-10,null,5], which represents the shown height balanced BST.
# Example 2:
#
# Input: head = []
# Output: []
# Example 3:
#
# Input: head = [0]
# Output: [0]
# Example 4:
#
# Input: head = [1,3]
# Output: [3,1]
#
#
# Constraints:
#
# The number of nodes in head is in the range [0, 2 * 104].
# -105 <= Node.val <= 105

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def sortedListToBST(self, head: ListNode) -> TreeNode:
        # recursion        
        if not head:
            return head
        if not head.next:
            return TreeNode(head.val)
        if not head.next.next:
            root = TreeNode(head.next.val)
            root.left = TreeNode(head.val)
            return root
        
        prev, slow, fast = ListNode(0), head, head
        prev.next = head
        while fast and fast.next:
            prev = slow
            slow = slow.next
            fast = fast.next.next
        prev.next = None # break off the linked list
        root = TreeNode(slow.val)
        root.left = self.sortedListToBST(head)
        root.right = self.sortedListToBST(slow.next)
        return root
    
        # a better recursion
        if not head:
            return head
        if not head.next:
            return TreeNode(head.val)
        
        prev, slow, fast = None, head, head
        while fast and fast.next:
            prev = slow
            slow = slow.next
            fast = fast.next.next
        prev.next = None # break off the linked list
        root = TreeNode(slow.val)
        root.left = self.sortedListToBST(head)
        root.right = self.sortedListToBST(slow.next)
        return root

# %%
class Solution:
    def sortedListToBST(self, head: ListNode) -> TreeNode:   
        # recursion with the help of a list
        li = []
        while head:
            li.append(head.val)
            head = head.next
        
         """if left > right, right is the index of the last node"""
        def list2BST(left, right):
            if left > right:
                return None
            mid = (left + right)//2
            root = TreeNode(li[mid])
            root.left = list2BST(left, mid - 1)
            root.right = list2BST(mid + 1, right)
            return root
        
        return list2BST(0, len(li) - 1)

# %%
class Solution:
    def sortedListToBST(self, head: ListNode) -> TreeNode:   
        # recursion with the help of a list
        li = []
        while head:
            li.append(head.val)
            head = head.next
        
        """if left >= right, right is the index of the last node + 1"""
        def list2BST(left, right):
            if left >= right:
                return None
            mid = (left + right)//2
            root = TreeNode(li[mid])
            root.left = list2BST(left, mid)
            root.right = list2BST(mid + 1, right)
            return root
        
        return list2BST(0, len(li))
