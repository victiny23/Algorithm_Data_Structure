# %% [markdown]
# 20. Valid Parentheses
# Easy
#
# 8833
#
# 350
#
# Add to List
#
# Share
# Given a string s containing just the characters '(', ')', '{', '}', '[' and ']', determine if the input string is valid.
#
# An input string is valid if:
#
# Open brackets must be closed by the same type of brackets.
# Open brackets must be closed in the correct order.
#
#
# Example 1:
#
# Input: s = "()"
# Output: true
# Example 2:
#
# Input: s = "()[]{}"
# Output: true
# Example 3:
#
# Input: s = "(]"
# Output: false
# Example 4:
#
# Input: s = "([)]"
# Output: false
# Example 5:
#
# Input: s = "{[]}"
# Output: true

# %%
class Solution:
    def isValid(self, s: str) -> bool:
        """
        1. if it's the left bracket then we append it to the stack
        2. else if it's the right bracket and the stack is empty(meaning no matching left bracket), 
            or the left bracket doesn't match
        3. finally check if the stack still contains unmatched left bracket
        """
        
        
        
        """Stack"""
        dic = {'{': '}', '(': ')', '[': ']'}
        stack = [s[0]]
        for i in range(1, len(s)):
            if not stack:
                stack.append(s[i])
            elif stack[-1] in dic and dic[stack[-1]] == s[i]:
                stack.pop()
            else:
                stack.append(s[i])
        return not stack
        
        
        
        """Stack"""
        dic = {'{': '}', '(': ')', '[': ']'}
        stack = []
        for p in s:
            if p in dic:
                stack.append(p)
            elif not stack or dic[stack.pop()] != p:
                return False
        return not stack
        
        
        
        """A trick for empty stack error"""
        dic = {')':'(',']':'[','}':'{'}
        stack = ['A']
        for p in s:
            if p in dic:
                if stack.pop() != dic[p]:
                    return False
            else:
                stack.append(p)
        return len(stack) == 1
