# %% [markdown]
# 40. Combination Sum II
# Medium
#
# 3556
#
# 103
#
# Add to List
#
# Share
# Given a collection of candidate numbers (candidates) and a target number (target), find all unique combinations in candidates where the candidate numbers sum to target.
#
# Each number in candidates may only be used once in the combination.
#
# Note: The solution set must not contain duplicate combinations.
#
#
#
# Example 1:
#
# Input: candidates = [10,1,2,7,6,1,5], target = 8
# Output:
# [
# [1,1,6],
# [1,2,5],
# [1,7],
# [2,6]
# ]
# Example 2:
#
# Input: candidates = [2,5,2,1,2], target = 5
# Output:
# [
# [1,2,2],
# [5]
# ]
#
#
# Constraints:
#
# 1 <= candidates.length <= 100
# 1 <= candidates[i] <= 50
# 1 <= target <= 30

# %%
class Solution:
    def combinationSum2(self, candidates: List[int], target: int) -> List[List[int]]:
        """
        Sort + Backtracking + Two Pointers to remove duplicates
        TLE! - must remove duplicates while building up the res
        cannot remove duplicates afterwards
        there might be too many combinations when duplicates are allowed
        e.g. [1,1,1,1,1,1] 20, each 1 can be used 20 times, there are 6^20 combos!!!
        """
        # if sum(candidates) < target:
        #     return []
        # def dfs(candidates, remain, combo):
        #     if remain < 0:
        #         return
        #     if remain == 0:
        #         res.append(combo)
        #         return
        #     for i in range(len(candidates)):
        #         if candidates[i] > remain:
        #             break
        #         dfs(candidates[i+1:], remain - candidates[i], combo + [candidates[i]])
        # candidates.sort()
        # res = []
        # dfs(candidates, target, [])
        # # remove duplicates
        # cnt = len(res)
        # if cnt == 1:
        #     return res
        # res.sort()
        # # slow pointer
        # prev = 0
        # # fast pointer
        # for i in range(1, cnt):
        #     if res[i] != res[prev]:
        #         prev += 1
        #         res[prev] = res[i]
        # return res[:prev+1]
       
        """ Sort + Backtracking: Sort is a must for this problem to avoid duplicates"""
        if sum(candidates) < target:
            return []
        def dfs(candidates, remain, combo):
            if remain < 0:
                return
            if remain == 0:
                res.append(combo)
                return
            for i in range(len(candidates)):
                if candidates[i] > remain:
                    break
                # keep going until a different candidate is found
                # otherwise the same candidate would generate duplicates
                if i > 0 and candidates[i] == candidates[i-1]:
                    continue
                dfs(candidates[i+1:], remain - candidates[i], combo + [candidates[i]])
        candidates.sort()
        res = []
        dfs(candidates, target, [])
        return res

# %%
class Solution:
    def combinationSum2(self, candidates: List[int], target: int) -> List[List[int]]:
         """Sort + Dynamic Programming + Set""" # refer to coin change
        # candidates.sort()
        # dp = [set() for _ in range(target + 1)]
        # dp[0].add(())
        # for candi in candidates: # each candidate in candidates
        #     for t in range(target, candi-1, -1): # candi <= each possible value <= target
        #         if candi > t:
        #             break
        #         if candi == t:
        #             dp[t].add((candi,))
        #         # dp[t - candi] are the combinations with sum equal to t - candi
        #         # check candi >= combo[-1] to avoid duplicated answers like [3,2,2], [2,3,2], [2,2,3]
        #         for combo in dp[t-candi]:
        #             dp[t].add(combo + (candi,))
        # return dp[target]
    
        # candi == t can be combined to the loop"""
        candidates.sort()
        dp = [set() for _ in range(target + 1)]
        # initialize
        dp[0].add(())
        # dp starts here
        for candi in candidates: # each candidate in candidates
            # do this in reverse order
            for t in range(target, candi-1, -1): # candi <= each possible value <= target
                if candi > t:
                    break
                # dp[t - candi] are the combinations with sum equal to t - candi
                for combo in dp[t-candi]:
                    dp[t].add(combo + (candi,))
        return dp[target]
