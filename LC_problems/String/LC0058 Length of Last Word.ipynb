# %% [markdown]
# 58. Length of Last Word
# Easy
#
# 18
#
# 3
#
# Add to List
#
# Share
# Given a string s consisting of some words separated by some number of spaces, return the length of the last word in the string.
#
# A word is a maximal substring consisting of non-space characters only.
#
#
#
# Example 1:
#
# Input: s = "Hello World"
# Output: 5
# Explanation: The words are "Hello" and "World", both of length 5.
# Example 2:
#
# Input: s = "   fly me   to   the moon  "
# Output: 4
# Explanation: The longest word is "moon" with length 4.
# Example 3:
#
# Input: s = "luffy is still joyboy"
# Output: 6
# Explanation: The longest word is "joyboy" with length 6.
#
#
# Constraints:
#
# 1 <= s.length <= 104
# s consists of only English letters and spaces ' '.
# There will be at least one word in s.

# %%
class Solution:
    def lengthOfLastWord(self, s: str) -> int:
        """remove the white space: s.rstrip(), s.lstrip(), s.strip()"""
        
        """find the last word - 28 ms"""
        s = s.rstrip()
        words = s.split(' ')
        return len(words[-1])
        
        
        """find ' ' to end from the right - 32 ms"""
        s = s.rstrip()
        if not s:
            return 0
        lol = 0
        for i in range(len(s)-1, -1, -1):
            if s[i] == ' ':
                return lol
            else:
                lol += 1
        return len(s)
        
        
        """find ' ' to end from the right - 20 ms"""
        if not s:
            return 0
        lol, ws = 0, 0
        for i in range(len(s)-1, -1, -1):
            if not lol and s[i] == ' ':
                ws += 1
            elif s[i] != ' ':
                lol += 1
            else:
                return lol
        return len(s) - ws
